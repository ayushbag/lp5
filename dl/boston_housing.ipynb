# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("boston_housing.csv")

print(df.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# -------------------------
# Step 2: Preprocess data
# -------------------------

from sklearn.preprocessing import StandardScaler

X = df.drop('medv', axis=1)

y = df['medv']

scaler = StandardScaler()
X = scaler.fit_transform(X)

print(X[:5])
# Out:
# [[-0.41978194  0.28482986 -1.2879095  -0.27259857 -0.14421743  0.41367189
#   -0.12001342  0.1402136  -0.98284286 -0.66660821 -1.45900038  0.44105193
#   -1.0755623 ]
#  [-0.41733926 -0.48772236 -0.59338101 -0.27259857 -0.74026221  0.19427445
#    0.36716642  0.55715988 -0.8678825  -0.98732948 -0.30309415  0.44105193
#   -0.49243937]
#  [-0.41734159 -0.48772236 -0.59338101 -0.27259857 -0.74026221  1.28271368
#   -0.26581176  0.55715988 -0.8678825  -0.98732948 -0.30309415  0.39642699
#   -1.2087274 ]
#  [-0.41675042 -0.48772236 -1.30687771 -0.27259857 -0.83528384  1.01630251
#   -0.80988851  1.07773662 -0.75292215 -1.10611514  0.1130321   0.41616284
#   -1.36151682]
#  [-0.41248185 -0.48772236 -1.30687771 -0.27259857 -0.83528384  1.22857665
#   -0.51117971  1.07773662 -0.75292215 -1.10611514  0.1130321   0.44105193
#   -1.02650148]]

# %%
# -------------------------
# Step 3: Train-test split
# -------------------------
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

print("Training set state:", X_train.shape, y_train.shape)
print("Testing set state:", X_test.shape, y_test.shape)
# Out:
# Training set state: (354, 13) (354,)
# Testing set state: (152, 13) (152,)

# %%
# -------------------------
# Step 4: Build model
# -------------------------
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()

model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

print(model.summary())
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,009 (11.75 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# -------------------------
# Step 5: Compile model
# -------------------------
model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mean_absolute_error']
)

# %%
# -------------------------
# Step 6: Train model
# -------------------------
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 614.2862 - mean_absolute_error: 22.8646 - val_loss: 561.5898 - val_mean_absolute_error: 22.2064
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 588.3634 - mean_absolute_error: 22.2785 - val_loss: 535.4908 - val_mean_absolute_error: 21.5991
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 558.3591 - mean_absolute_error: 21.5767 - val_loss: 506.1942 - val_mean_absolute_error: 20.9050
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 524.6605 - mean_absolute_error: 20.7553 - val_loss: 471.5044 - val_mean_absolute_error: 20.0639
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 485.3993 - mean_absolute_error: 19.7946 - val_loss: 429.3088 - val_mean_absolute_error: 19.0075
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 435.7010 - mean_absolute_error: 18.5856 - val_loss: 378.4792 - val_mean_absolute_error: 17.6610
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 377.3327 - mean_absolute_error: 17.0374 - val_loss: 319.7780 - val_mean_absolute_error: 16.0638
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 308.9301 - mean_absolute_error: 15.1707 - val_loss: 254.1384 - val_mean_absolute_error: 14.1117
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 247.4488 - mean_absolute_error: 13.3249 - val_loss: 186.0269 - val_mean_absolute_error: 11.7601
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 173.4515 - mean_absolute_error: 10.7762 - val_loss: 126.1667 - val_mean_absolute_error: 9.2354
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 124.8343 - mean_absolute_error: 8.9441 - val_loss: 83.7805 - val_mean_absolute_error: 7.0752
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 87.0421 - mean_absolute_error: 7.3545 - val_loss: 60.3368 - val_mean_absolute_error: 5.7900
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 69.4944 - mean_absolute_error: 6.4065 - val_loss: 47.9667 - val_mean_absolute_error: 5.1363
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 59.3949 - mean_absolute_error: 5.9973 - val_loss: 41.2702 - val_mean_absolute_error: 4.6886
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 54.4225 - mean_absolute_error: 5.5946 - val_loss: 36.1145 - val_mean_absolute_error: 4.2904
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 42.8434 - mean_absolute_error: 5.0153 - val_loss: 33.2420 - val_mean_absolute_error: 4.0703
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 39.8579 - mean_absolute_error: 4.6092 - val_loss: 31.8062 - val_mean_absolute_error: 3.9769
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 40.5160 - mean_absolute_error: 4.5281 - val_loss: 31.1750 - val_mean_absolute_error: 3.9527
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 35.6553 - mean_absolute_error: 4.5168 - val_loss: 30.7218 - val_mean_absolute_error: 3.9354
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 33.0829 - mean_absolute_error: 4.2525 - val_loss: 30.0995 - val_mean_absolute_error: 3.9010
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 29.7039 - mean_absolute_error: 4.0604 - val_loss: 29.8353 - val_mean_absolute_error: 3.8873
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 32.8741 - mean_absolute_error: 4.2940 - val_loss: 29.7331 - val_mean_absolute_error: 3.8811
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 30.5051 - mean_absolute_error: 4.0123 - val_loss: 28.8890 - val_mean_absolute_error: 3.8244
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 27.9382 - mean_absolute_error: 3.9443 - val_loss: 28.6102 - val_mean_absolute_error: 3.7950
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 26.2768 - mean_absolute_error: 3.8015 - val_loss: 28.1883 - val_mean_absolute_error: 3.7632
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.4476 - mean_absolute_error: 3.9883 - val_loss: 27.7284 - val_mean_absolute_error: 3.7252
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 26.6418 - mean_absolute_error: 3.9081 - val_loss: 27.3552 - val_mean_absolute_error: 3.6823
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 27.5121 - mean_absolute_error: 3.9762 - val_loss: 27.0328 - val_mean_absolute_error: 3.6368
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26.9281 - mean_absolute_error: 3.9177 - val_loss: 26.5217 - val_mean_absolute_error: 3.5933
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 25.9342 - mean_absolute_error: 3.9538 - val_loss: 25.9493 - val_mean_absolute_error: 3.5494
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.5621 - mean_absolute_error: 3.6180 - val_loss: 25.5504 - val_mean_absolute_error: 3.5126
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.4450 - mean_absolute_error: 3.8426 - val_loss: 25.1185 - val_mean_absolute_error: 3.4891
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26.9883 - mean_absolute_error: 3.8905 - val_loss: 24.5743 - val_mean_absolute_error: 3.4589
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 25.0060 - mean_absolute_error: 3.7124 - val_loss: 24.2356 - val_mean_absolute_error: 3.4355
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.3863 - mean_absolute_error: 3.5331 - val_loss: 23.5734 - val_mean_absolute_error: 3.3899
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.2838 - mean_absolute_error: 3.6730 - val_loss: 23.5740 - val_mean_absolute_error: 3.4029
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 22.4505 - mean_absolute_error: 3.6121 - val_loss: 23.9324 - val_mean_absolute_error: 3.4282
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.8731 - mean_absolute_error: 3.3824 - val_loss: 23.5664 - val_mean_absolute_error: 3.3996
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.7586 - mean_absolute_error: 3.4248 - val_loss: 23.2245 - val_mean_absolute_error: 3.3618
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 23.1676 - mean_absolute_error: 3.5893 - val_loss: 22.7254 - val_mean_absolute_error: 3.3240
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.8033 - mean_absolute_error: 3.5427 - val_loss: 22.8180 - val_mean_absolute_error: 3.3298
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 19.9426 - mean_absolute_error: 3.4147 - val_loss: 22.5065 - val_mean_absolute_error: 3.2938
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.7017 - mean_absolute_error: 3.4894 - val_loss: 22.0845 - val_mean_absolute_error: 3.2516
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.5899 - mean_absolute_error: 3.3280 - val_loss: 21.7963 - val_mean_absolute_error: 3.2498
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.4760 - mean_absolute_error: 3.4453 - val_loss: 21.6046 - val_mean_absolute_error: 3.2420
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 21.5729 - mean_absolute_error: 3.4464 - val_loss: 21.3277 - val_mean_absolute_error: 3.2000
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.3361 - mean_absolute_error: 3.3805 - val_loss: 21.1038 - val_mean_absolute_error: 3.1862
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.2035 - mean_absolute_error: 3.1274 - val_loss: 20.8794 - val_mean_absolute_error: 3.1800
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 19.7770 - mean_absolute_error: 3.4418 - val_loss: 20.7930 - val_mean_absolute_error: 3.1797
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.6634 - mean_absolute_error: 3.3554 - val_loss: 21.1067 - val_mean_absolute_error: 3.2142
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.6452 - mean_absolute_error: 3.3988 - val_loss: 20.7679 - val_mean_absolute_error: 3.1962
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.9082 - mean_absolute_error: 3.4681 - val_loss: 20.3980 - val_mean_absolute_error: 3.1623
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.9514 - mean_absolute_error: 3.1421 - val_loss: 20.3262 - val_mean_absolute_error: 3.1452
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.1396 - mean_absolute_error: 3.2328 - val_loss: 19.6373 - val_mean_absolute_error: 3.0834
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.0431 - mean_absolute_error: 3.1433 - val_loss: 19.6402 - val_mean_absolute_error: 3.0902
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.9435 - mean_absolute_error: 3.3749 - val_loss: 19.4624 - val_mean_absolute_error: 3.0875
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.5071 - mean_absolute_error: 3.2517 - val_loss: 19.5602 - val_mean_absolute_error: 3.0993
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.2797 - mean_absolute_error: 3.2530 - val_loss: 19.5686 - val_mean_absolute_error: 3.1006
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.9273 - mean_absolute_error: 3.2121 - val_loss: 19.2970 - val_mean_absolute_error: 3.0885
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.0151 - mean_absolute_error: 3.3328 - val_loss: 18.9400 - val_mean_absolute_error: 3.0700
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 20.3063 - mean_absolute_error: 3.3700 - val_loss: 18.8319 - val_mean_absolute_error: 3.0332
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.0719 - mean_absolute_error: 3.1692 - val_loss: 18.5351 - val_mean_absolute_error: 3.0034
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.5897 - mean_absolute_error: 3.2589 - val_loss: 18.5452 - val_mean_absolute_error: 3.0137
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.5888 - mean_absolute_error: 2.9858 - val_loss: 18.5037 - val_mean_absolute_error: 3.0213
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17.5124 - mean_absolute_error: 3.1518 - val_loss: 18.8453 - val_mean_absolute_error: 3.0587
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.5749 - mean_absolute_error: 3.1453 - val_loss: 18.0935 - val_mean_absolute_error: 2.9917
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.4213 - mean_absolute_error: 2.9859 - val_loss: 17.9492 - val_mean_absolute_error: 2.9670
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.5376 - mean_absolute_error: 3.1667 - val_loss: 17.7995 - val_mean_absolute_error: 2.9666
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 15.1912 - mean_absolute_error: 3.0320 - val_loss: 18.0440 - val_mean_absolute_error: 3.0070
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.3582 - mean_absolute_error: 3.0291 - val_loss: 18.0248 - val_mean_absolute_error: 3.0229
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.9763 - mean_absolute_error: 3.2153 - val_loss: 17.3384 - val_mean_absolute_error: 2.9384
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 15.4654 - mean_absolute_error: 3.0250 - val_loss: 17.4914 - val_mean_absolute_error: 2.9367
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.3819 - mean_absolute_error: 2.9635 - val_loss: 17.5889 - val_mean_absolute_error: 2.9688
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.9368 - mean_absolute_error: 2.9965 - val_loss: 17.8097 - val_mean_absolute_error: 3.0115
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.0667 - mean_absolute_error: 2.8581 - val_loss: 17.4421 - val_mean_absolute_error: 2.9931
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.0339 - mean_absolute_error: 2.9302 - val_loss: 17.4436 - val_mean_absolute_error: 2.9979

# %%
# -------------------------
# Plot loss
# -------------------------
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'])
plt.show()

# %%
# -------------------------
# Step 7: Evaluate model
# -------------------------
loss, mae = model.evaluate(X_test, y_test)

print("Mean Absolute Error:", mae)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13.0581 - mean_absolute_error: 2.3856
# Mean Absolute Error: 2.385648727416992

# %%
# final flow of exec

#Data → Preprocessing → Train-Test Split
     # → Neural Network
     # → Compile (rules)
     # → Training (learning)
     # → Loss Graph (analysis)
     # → Evaluation (final performance)
